# %% [markdown]
# ### Note
# * This is data import for gdp_data and population_data

# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt

# Import population and gdp csv files
population = r"C:\Git\WorldBank_ETL\Resources\population_data.csv"
gdp = r"C:\Git\WorldBank_ETL\Resources\gdp_data.csv"
# Read Purchasing File and store into Pandas data frame
population_df = pd.read_csv(population)
gdp_df = pd.read_csv(gdp)

# %% [markdown]
# ## Display Dataframes

# %%
population_df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.178047e+08  1.193879e+08  1.215043e+08  1.241388e+08  1.267943e+08
# std    3.718380e+08  3.763000e+08  3.828567e+08  3.914029e+08  3.999940e+08
# min    4.279000e+03  4.453000e+03  4.566000e+03  4.656000e+03  4.748000e+03
# 25%    5.184015e+05  5.301480e+05  5.426568e+05  5.559520e+05  5.684168e+05
# 50%    3.669524e+06  3.734206e+06  3.839584e+06  3.955168e+06  4.074411e+06
# 75%    2.532754e+07  2.611541e+07  2.690508e+07  2.770050e+07  2.847884e+07
# max    3.032160e+09  3.073369e+09  3.126510e+09  3.191786e+09  3.257460e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.295161e+08  1.323830e+08  1.352449e+08  1.381576e+08  1.412127e+08
# std    4.088230e+08  4.182201e+08  4.275709e+08  4.371272e+08  4.471654e+08
# min    4.841000e+03  4.936000e+03  5.033000e+03  5.161000e+03  5.303000e+03
# 25%    5.727790e+05  5.786500e+05  5.882328e+05  6.257960e+05  6.567582e+05
# 50%    4.170862e+06  4.235562e+06  4.300502e+06  4.367325e+06  4.449014e+06
# 75%    2.924750e+07  2.999693e+07  3.059503e+07  3.120239e+07  3.179527e+07
# max    3.324545e+09  3.394784e+09  3.464689e+09  3.535355e+09  3.610179e+09
#
#        ...          2008          2009          2010          2011  \
# count  ...  2.630000e+02  2.630000e+02  2.630000e+02  2.630000e+02
# mean   ...  2.700922e+08  2.736009e+08  2.771312e+08  2.806502e+08
# std    ...  8.590623e+08  8.695613e+08  8.801281e+08  8.907357e+08
# min    ...  9.947000e+03  9.945000e+03  1.002500e+04  1.005700e+04
# 25%    ...  1.363216e+06  1.425982e+06  1.443678e+06  1.465471e+06
# 50%    ...  9.219637e+06  9.298515e+06  9.378126e+06  9.460802e+06
# 75%    ...  4.994594e+07  5.038575e+07  5.087028e+07  5.140827e+07
# max    ...  6.766297e+09  6.849569e+09  6.932870e+09  7.014984e+09
#
#                2012          2013          2014          2015          2016  \
# count  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02
# mean   2.853281e+08  2.890029e+08  2.927066e+08  2.964194e+08  3.001537e+08
# std    9.030998e+08  9.140529e+08  9.250713e+08  9.361003e+08  9.471857e+08
# min    1.027900e+04  1.081900e+04  1.090800e+04  1.100100e+04  1.109700e+04
# 25%    1.415726e+06  1.431560e+06  1.447306e+06  1.471523e+06  1.522803e+06
# 50%    9.624267e+06  9.746730e+06  9.879129e+06  1.002115e+07  1.012427e+07
# 75%    5.249529e+07  5.318760e+07  5.396340e+07  5.493841e+07  5.590466e+07
# max    7.099558e+09  7.185138e+09  7.271323e+09  7.357559e+09  7.444157e+09
#
#                2017
# count  2.620000e+02
# mean   3.038840e+08
# std    9.582593e+08
# min    1.119200e+04
# 25%    1.577113e+06
# 50%    1.018073e+07
# 75%    5.716180e+07
# max    7.530360e+09
#
# [8 rows x 58 columns]

# %%
population_df.head(10)
# Out:
#            Country Name Country Code     Indicator Name Indicator Code  \
# 0                 Aruba          ABW  Population, total    SP.POP.TOTL
# 1           Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2                Angola          AGO  Population, total    SP.POP.TOTL
# 3               Albania          ALB  Population, total    SP.POP.TOTL
# 4               Andorra          AND  Population, total    SP.POP.TOTL
# 5            Arab World          ARB  Population, total    SP.POP.TOTL
# 6  United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 7             Argentina          ARG  Population, total    SP.POP.TOTL
# 8               Armenia          ARM  Population, total    SP.POP.TOTL
# 9        American Samoa          ASM  Population, total    SP.POP.TOTL
#
#          1960        1961        1962         1963         1964         1965  \
# 0     54211.0     55438.0     56225.0      56695.0      57032.0      57360.0
# 1   8996351.0   9166764.0   9345868.0    9533954.0    9731361.0    9938414.0
# 2   5643182.0   5753024.0   5866061.0    5980417.0    6093321.0    6203299.0
# 3   1608800.0   1659800.0   1711319.0    1762621.0    1814135.0    1864791.0
# 4     13411.0     14375.0     15370.0      16412.0      17469.0      18549.0
# 5  92490932.0  95044497.0  97682294.0  100411076.0  103239902.0  106174988.0
# 6     92634.0    101078.0    112472.0     125566.0     138529.0     150362.0
# 7  20619075.0  20953077.0  21287682.0   21621840.0   21953929.0   22283390.0
# 8   1874120.0   1941491.0   2009526.0    2077575.0    2144998.0    2211316.0
# 9     20013.0     20486.0     21117.0      21882.0      22698.0      23520.0
#
#    ...         2008         2009         2010         2011         2012  \
# 0  ...     101353.0     101453.0     101669.0     102053.0     102577.0
# 1  ...   27294031.0   28004331.0   28803167.0   29708599.0   30696958.0
# 2  ...   21759420.0   22549547.0   23369131.0   24218565.0   25096150.0
# 3  ...    2947314.0    2927519.0    2913021.0    2905195.0    2900401.0
# 4  ...      83861.0      84462.0      84449.0      83751.0      82431.0
# 5  ...  339825483.0  348145094.0  356508908.0  364895878.0  373306993.0
# 6  ...    6894278.0    7666393.0    8270684.0    8672475.0    8900453.0
# 7  ...   40382389.0   40799407.0   41223889.0   41656879.0   42096739.0
# 8  ...    2908220.0    2888584.0    2877311.0    2875581.0    2881922.0
# 9  ...      57030.0      56227.0      55637.0      55320.0      55230.0
#
#           2013         2014         2015         2016         2017
# 0     103187.0     103795.0     104341.0     104822.0     105264.0
# 1   31731688.0   32758020.0   33736494.0   34656032.0   35530081.0
# 2   25998340.0   26920466.0   27859305.0   28813463.0   29784193.0
# 3    2895092.0    2889104.0    2880703.0    2876101.0    2873457.0
# 4      80788.0      79223.0      78014.0      77281.0      76965.0
# 5  381702086.0  390043028.0  398304960.0  406452690.0  414491886.0
# 6    9006263.0    9070867.0    9154302.0    9269612.0    9400145.0
# 7   42539925.0   42981515.0   43417765.0   43847430.0   44271041.0
# 8    2893509.0    2906220.0    2916950.0    2924816.0    2930450.0
# 9      55307.0      55437.0      55537.0      55599.0      55641.0
#
# [10 rows x 62 columns]

# %%
gdp_df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  1.240000e+02  1.240000e+02  1.250000e+02  1.250000e+02  1.250000e+02
# mean   7.074121e+10  7.352259e+10  7.801655e+10  8.452492e+10  9.299526e+10
# std    2.186629e+11  2.294491e+11  2.461078e+11  2.652890e+11  2.902428e+11
# min    1.201203e+07  1.159202e+07  9.122751e+06  1.084010e+07  1.271247e+07
# 25%    4.930171e+08  4.891902e+08  4.791808e+08  5.119021e+08  5.425784e+08
# 50%    1.988240e+09  2.074604e+09  2.174966e+09  2.510127e+09  2.766609e+09
# 75%    1.484928e+10  1.585175e+10  1.659254e+10  1.895413e+10  2.113724e+10
# max    1.350000e+12  1.410000e+12  1.510000e+12  1.630000e+12  1.790000e+12
#
#                1965          1966          1967          1968          1969  \
# count  1.360000e+02  1.370000e+02  1.410000e+02  1.450000e+02  1.450000e+02
# mean   9.742800e+10  1.043055e+11  1.108074e+11  1.160376e+11  1.277621e+11
# std    3.050386e+11  3.313321e+11  3.503271e+11  3.735817e+11  4.097716e+11
# min    1.359393e+07  1.446908e+07  1.583518e+07  1.460000e+07  1.585000e+07
# 25%    5.199337e+08  5.499500e+08  4.515241e+08  4.851608e+08  5.512373e+08
# 50%    2.784309e+09  2.876396e+09  3.046339e+09  3.271416e+09  3.651615e+09
# 75%    2.219508e+10  2.432000e+10  2.656000e+10  2.914338e+10  3.164920e+10
# max    1.950000e+12  2.110000e+12  2.250000e+12  2.430000e+12  2.670000e+12
#
#        ...          2008          2009          2010          2011  \
# count  ...  2.490000e+02  2.490000e+02  2.490000e+02  2.500000e+02
# mean   ...  2.028965e+12  1.924557e+12  2.140276e+12  2.394450e+12
# std    ...  7.159464e+12  6.764026e+12  7.328021e+12  8.092282e+12
# min    ...  3.029022e+07  2.710108e+07  3.182352e+07  3.871183e+07
# 25%    ...  6.109928e+09  5.832915e+09  6.959697e+09  7.674355e+09
# 50%    ...  3.913689e+10  3.744067e+10  4.028448e+10  4.586291e+10
# 75%    ...  5.100000e+11  4.290000e+11  4.840000e+11  5.297500e+11
# max    ...  6.340000e+13  6.010000e+13  6.600000e+13  7.330000e+13
#
#                2012          2013          2014          2015          2016  \
# count  2.470000e+02  2.480000e+02  2.470000e+02  2.460000e+02  2.410000e+02
# mean   2.489432e+12  2.568772e+12  2.653541e+12  2.505533e+12  2.586350e+12
# std    8.298978e+12  8.521828e+12  8.765280e+12  8.319552e+12  8.527211e+12
# min    3.767173e+07  3.750912e+07  3.729059e+07  3.555604e+07  3.657261e+07
# 25%    8.681057e+09  8.994685e+09  1.019047e+10  8.757940e+09  9.412034e+09
# 50%    5.038845e+10  5.447389e+10  5.673199e+10  5.317434e+10  5.324089e+10
# 75%    5.550000e+11  5.587500e+11  5.710000e+11  5.787500e+11  6.450000e+11
# max    7.500000e+13  7.710000e+13  7.910000e+13  7.480000e+13  7.590000e+13
#
#                2017
# count  2.340000e+02
# mean   2.847698e+12
# std    9.177370e+12
# min    3.973132e+07
# 25%    1.150900e+10
# 50%    5.944777e+10
# 75%    7.177500e+11
# max    8.070000e+13
#
# [8 rows x 58 columns]

# %%
gdp_df.head(10)
# Out:
#            Country Name Country Code     Indicator Name  Indicator Code  \
# 0                 Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1           Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2                Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3               Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4               Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# 5            Arab World          ARB  GDP (current US$)  NY.GDP.MKTP.CD
# 6  United Arab Emirates          ARE  GDP (current US$)  NY.GDP.MKTP.CD
# 7             Argentina          ARG  GDP (current US$)  NY.GDP.MKTP.CD
# 8               Armenia          ARM  GDP (current US$)  NY.GDP.MKTP.CD
# 9        American Samoa          ASM  GDP (current US$)  NY.GDP.MKTP.CD
#
#           1960         1961         1962         1963         1964  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1  537777811.1  548888895.6  546666677.8  751111191.1  800000044.4
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
#
#            1965  ...          2008          2009          2010          2011  \
# 0           NaN  ...  2.791961e+09  2.498933e+09  2.467704e+09  2.584464e+09
# 1  1.006667e+09  ...  1.019053e+10  1.248694e+10  1.593680e+10  1.793024e+10
# 2           NaN  ...  8.417804e+10  7.549239e+10  8.252614e+10  1.040000e+11
# 3           NaN  ...  1.288135e+10  1.204421e+10  1.192695e+10  1.289087e+10
# 4           NaN  ...  4.007353e+09  3.660531e+09  3.355695e+09  3.442063e+09
# 5           NaN  ...  2.080000e+12  1.800000e+12  2.110000e+12  2.500000e+12
# 6           NaN  ...  3.150000e+11  2.540000e+11  2.900000e+11  3.510000e+11
# 7           NaN  ...  3.620000e+11  3.330000e+11  4.240000e+11  5.300000e+11
# 8           NaN  ...  1.166204e+10  8.647937e+09  9.260285e+09  1.014211e+10
# 9           NaN  ...  5.630000e+08  6.780000e+08  5.760000e+08  5.740000e+08
#
#            2012          2013          2014          2015          2016  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.053654e+10  2.026425e+10  2.061610e+10  1.921556e+10  1.946902e+10
# 2  1.140000e+11  1.250000e+11  1.270000e+11  1.030000e+11  9.533720e+10
# 3  1.231978e+10  1.277628e+10  1.322824e+10  1.138693e+10  1.188368e+10
# 4  3.164615e+09  3.281585e+09  3.350736e+09  2.811489e+09  2.877312e+09
# 5  2.790000e+12  2.870000e+12  2.910000e+12  2.550000e+12  2.500000e+12
# 6  3.750000e+11  3.900000e+11  4.030000e+11  3.580000e+11  3.570000e+11
# 7  5.460000e+11  5.520000e+11  5.260000e+11  5.950000e+11  5.550000e+11
# 8  1.061932e+10  1.112147e+10  1.160951e+10  1.055334e+10  1.054614e+10
# 9  6.440000e+08  6.410000e+08  6.430000e+08  6.590000e+08  6.580000e+08
#
#            2017
# 0           NaN
# 1  2.081530e+10
# 2  1.240000e+11
# 3  1.303935e+10
# 4  3.012914e+09
# 5  2.590000e+12
# 6  3.830000e+11
# 7  6.380000e+11
# 8  1.153659e+10
# 9           NaN
#
# [10 rows x 62 columns]

# %% [markdown]
# #Display all the columns in data frames

# %%
gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2008          2009          2010          2011          2012  \
# 0  2.791961e+09  2.498933e+09  2.467704e+09  2.584464e+09           NaN
# 1  1.019053e+10  1.248694e+10  1.593680e+10  1.793024e+10  2.053654e+10
# 2  8.417804e+10  7.549239e+10  8.252614e+10  1.040000e+11  1.140000e+11
# 3  1.288135e+10  1.204421e+10  1.192695e+10  1.289087e+10  1.231978e+10
# 4  4.007353e+09  3.660531e+09  3.355695e+09  3.442063e+09  3.164615e+09
#
#            2013          2014          2015          2016          2017
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.026425e+10  2.061610e+10  1.921556e+10  1.946902e+10  2.081530e+10
# 2  1.250000e+11  1.270000e+11  1.030000e+11  9.533720e+10  1.240000e+11
# 3  1.277628e+10  1.322824e+10  1.138693e+10  1.188368e+10  1.303935e+10
# 4  3.281585e+09  3.350736e+09  2.811489e+09  2.877312e+09  3.012914e+09
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Display Dataframes

# %%
#Mekt gdp_df year columns under a Year column

# %%
gdp_combined_df = gdp_df.melt(id_vars = ["Country Name", "Country Code", "Indicator Name", "Indicator Code"], value_vars = ["1960", "1961",\
"1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978",\
"1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995",\
"1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012",\
"2013","2014","2015","2016","2017"], var_name = "Year", value_name = "GDP")

# %%
gdp_combined_df
# Out:
#        Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 0             Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 1       Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 2            Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 3           Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 4           Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD  1960
# ...             ...          ...                ...             ...   ...
# 15307        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD  2017
# 15308   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD  2017
# 15309  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD  2017
# 15310        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD  2017
# 15311      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD  2017
#
#                 GDP
# 0               NaN
# 1      5.377778e+08
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 15307  7.128691e+09
# 15308           NaN
# 15309  3.490000e+11
# 15310  2.580867e+10
# 15311  1.784582e+10
#
# [15312 rows x 6 columns]

# %% [markdown]
# #Melt population_df so year columns are under Year column

# %%
population_combined_df = population_df.melt(id_vars = ["Country Name", "Country Code", "Indicator Name", "Indicator Code"], value_vars = ["1960", "1961",\
"1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978",\
"1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995",\
"1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012",\
"2013","2014","2015","2016","2017"], var_name = "Year", value_name = "Population")

# %%
population_combined_df
# Out:
#        Country Name Country Code     Indicator Name Indicator Code  Year  \
# 0             Aruba          ABW  Population, total    SP.POP.TOTL  1960
# 1       Afghanistan          AFG  Population, total    SP.POP.TOTL  1960
# 2            Angola          AGO  Population, total    SP.POP.TOTL  1960
# 3           Albania          ALB  Population, total    SP.POP.TOTL  1960
# 4           Andorra          AND  Population, total    SP.POP.TOTL  1960
# ...             ...          ...                ...            ...   ...
# 15307        Kosovo          XKX  Population, total    SP.POP.TOTL  2017
# 15308   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL  2017
# 15309  South Africa          ZAF  Population, total    SP.POP.TOTL  2017
# 15310        Zambia          ZMB  Population, total    SP.POP.TOTL  2017
# 15311      Zimbabwe          ZWE  Population, total    SP.POP.TOTL  2017
#
#        Population
# 0         54211.0
# 1       8996351.0
# 2       5643182.0
# 3       1608800.0
# 4         13411.0
# ...           ...
# 15307   1830700.0
# 15308  28250420.0
# 15309  56717156.0
# 15310  17094130.0
# 15311  16529904.0
#
# [15312 rows x 6 columns]

# %%
Aruba_pop = population_combined_df[(population_combined_df["Country Name"] == "Aruba")]

# %%
Aruba_pop
# Out:
#       Country Name Country Code     Indicator Name Indicator Code  Year  \
# 0            Aruba          ABW  Population, total    SP.POP.TOTL  1960
# 264          Aruba          ABW  Population, total    SP.POP.TOTL  1961
# 528          Aruba          ABW  Population, total    SP.POP.TOTL  1962
# 792          Aruba          ABW  Population, total    SP.POP.TOTL  1963
# 1056         Aruba          ABW  Population, total    SP.POP.TOTL  1964
# 1320         Aruba          ABW  Population, total    SP.POP.TOTL  1965
# 1584         Aruba          ABW  Population, total    SP.POP.TOTL  1966
# 1848         Aruba          ABW  Population, total    SP.POP.TOTL  1967
# 2112         Aruba          ABW  Population, total    SP.POP.TOTL  1968
# 2376         Aruba          ABW  Population, total    SP.POP.TOTL  1969
# 2640         Aruba          ABW  Population, total    SP.POP.TOTL  1970
# 2904         Aruba          ABW  Population, total    SP.POP.TOTL  1971
# 3168         Aruba          ABW  Population, total    SP.POP.TOTL  1972
# 3432         Aruba          ABW  Population, total    SP.POP.TOTL  1973
# 3696         Aruba          ABW  Population, total    SP.POP.TOTL  1974
# 3960         Aruba          ABW  Population, total    SP.POP.TOTL  1975
# 4224         Aruba          ABW  Population, total    SP.POP.TOTL  1976
# 4488         Aruba          ABW  Population, total    SP.POP.TOTL  1977
# 4752         Aruba          ABW  Population, total    SP.POP.TOTL  1978
# 5016         Aruba          ABW  Population, total    SP.POP.TOTL  1979
# 5280         Aruba          ABW  Population, total    SP.POP.TOTL  1980
# 5544         Aruba          ABW  Population, total    SP.POP.TOTL  1981
# 5808         Aruba          ABW  Population, total    SP.POP.TOTL  1982
# 6072         Aruba          ABW  Population, total    SP.POP.TOTL  1983
# 6336         Aruba          ABW  Population, total    SP.POP.TOTL  1984
# 6600         Aruba          ABW  Population, total    SP.POP.TOTL  1985
# 6864         Aruba          ABW  Population, total    SP.POP.TOTL  1986
# 7128         Aruba          ABW  Population, total    SP.POP.TOTL  1987
# 7392         Aruba          ABW  Population, total    SP.POP.TOTL  1988
# 7656         Aruba          ABW  Population, total    SP.POP.TOTL  1989
# 7920         Aruba          ABW  Population, total    SP.POP.TOTL  1990
# 8184         Aruba          ABW  Population, total    SP.POP.TOTL  1991
# 8448         Aruba          ABW  Population, total    SP.POP.TOTL  1992
# 8712         Aruba          ABW  Population, total    SP.POP.TOTL  1993
# 8976         Aruba          ABW  Population, total    SP.POP.TOTL  1994
# 9240         Aruba          ABW  Population, total    SP.POP.TOTL  1995
# 9504         Aruba          ABW  Population, total    SP.POP.TOTL  1996
# 9768         Aruba          ABW  Population, total    SP.POP.TOTL  1997
# 10032        Aruba          ABW  Population, total    SP.POP.TOTL  1998
# 10296        Aruba          ABW  Population, total    SP.POP.TOTL  1999
# 10560        Aruba          ABW  Population, total    SP.POP.TOTL  2000
# 10824        Aruba          ABW  Population, total    SP.POP.TOTL  2001
# 11088        Aruba          ABW  Population, total    SP.POP.TOTL  2002
# 11352        Aruba          ABW  Population, total    SP.POP.TOTL  2003
# 11616        Aruba          ABW  Population, total    SP.POP.TOTL  2004
# 11880        Aruba          ABW  Population, total    SP.POP.TOTL  2005
# 12144        Aruba          ABW  Population, total    SP.POP.TOTL  2006
# 12408        Aruba          ABW  Population, total    SP.POP.TOTL  2007
# 12672        Aruba          ABW  Population, total    SP.POP.TOTL  2008
# 12936        Aruba          ABW  Population, total    SP.POP.TOTL  2009
# 13200        Aruba          ABW  Population, total    SP.POP.TOTL  2010
# 13464        Aruba          ABW  Population, total    SP.POP.TOTL  2011
# 13728        Aruba          ABW  Population, total    SP.POP.TOTL  2012
# 13992        Aruba          ABW  Population, total    SP.POP.TOTL  2013
# 14256        Aruba          ABW  Population, total    SP.POP.TOTL  2014
# 14520        Aruba          ABW  Population, total    SP.POP.TOTL  2015
# 14784        Aruba          ABW  Population, total    SP.POP.TOTL  2016
# 15048        Aruba          ABW  Population, total    SP.POP.TOTL  2017
#
#        Population
# 0         54211.0
# 264       55438.0
# 528       56225.0
# 792       56695.0
# 1056      57032.0
# 1320      57360.0
# 1584      57715.0
# 1848      58055.0
# 2112      58386.0
# 2376      58726.0
# 2640      59063.0
# 2904      59440.0
# 3168      59840.0
# 3432      60243.0
# 3696      60528.0
# 3960      60657.0
# 4224      60586.0
# 4488      60366.0
# 4752      60103.0
# 5016      59980.0
# 5280      60096.0
# 5544      60567.0
# 5808      61345.0
# 6072      62201.0
# 6336      62836.0
# 6600      63026.0
# 6864      62644.0
# 7128      61833.0
# 7392      61079.0
# 7656      61032.0
# 7920      62149.0
# 8184      64622.0
# 8448      68235.0
# 8712      72504.0
# 8976      76700.0
# 9240      80324.0
# 9504      83200.0
# 9768      85451.0
# 10032     87277.0
# 10296     89005.0
# 10560     90853.0
# 10824     92898.0
# 11088     94992.0
# 11352     97017.0
# 11616     98737.0
# 11880    100031.0
# 12144    100832.0
# 12408    101220.0
# 12672    101353.0
# 12936    101453.0
# 13200    101669.0
# 13464    102053.0
# 13728    102577.0
# 13992    103187.0
# 14256    103795.0
# 14520    104341.0
# 14784    104822.0
# 15048    105264.0

# %%
Aruba_gdp = gdp_combined_df[(gdp_combined_df["Country Name"] == "Aruba")]

# %%
Aruba_gdp.head()
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  Year  GDP
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1960  NaN
# 264         Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1961  NaN
# 528         Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1962  NaN
# 792         Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1963  NaN
# 1056        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1964  NaN

# %%
year_x = population_combined_df["Year"]
population_y = population_combined_df["Population"]



plt.plot(year_x,population_y)
plt.title('Population By Year')
plt.xlabel('Year')
plt.ylabel('Population Number')
plt.show()

# %%
result = population_combined_df.loc(["Country Name"] == "Not classified")
print(result)
# Out:
# <pandas.core.indexing._LocIndexer object at 0x000001FE8A517540>

# %%
# Set the index of the DataFrame to the country name
population_combined_country_index = population_combined_df.set_index("Country Name")
population_combined_country_index.head()
# Out:
#              Country Code     Indicator Name Indicator Code  Year  Population
# Country Name
# Aruba                 ABW  Population, total    SP.POP.TOTL  1960     54211.0
# Afghanistan           AFG  Population, total    SP.POP.TOTL  1960   8996351.0
# Angola                AGO  Population, total    SP.POP.TOTL  1960   5643182.0
# Albania               ALB  Population, total    SP.POP.TOTL  1960   1608800.0
# Andorra               AND  Population, total    SP.POP.TOTL  1960     13411.0

# %%
len(population_combined_country_index.index)
# Out:
# 15312

# %%
# With the index, we can drop the rows for a single country with its name
population_combined_country_indx = population_combined_country_index.drop("Not classified")

# %%
len(population_combined_country_indx.index)
# Out:
# 15254

# %%
#Reset index
pop_data_df = population_combined_country_indx.reset_index()

# %%
pop_data_df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code  Year  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL  1960
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  1960
# 2       Angola          AGO  Population, total    SP.POP.TOTL  1960
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1960
# 4      Andorra          AND  Population, total    SP.POP.TOTL  1960
#
#    Population
# 0     54211.0
# 1   8996351.0
# 2   5643182.0
# 3   1608800.0
# 4     13411.0

# %%
pop_data_df["Year"] = pop_data_df['Year'].astype(str).astype(int)
print(pop_data_df.dtypes)
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# Year                int32
# Population        float64
# dtype: object

# %%
len(pop_data_df)
# Out:
# 15254

# %%
# remove rows using the drop() function
pop_data_df.drop(pop_data_df.loc[pop_data_df['Year'] <= 1999].index, inplace=True)
pop_data_clean = pop_data_df
# display the dataframe
pop_data_clean.head()
# Out:
#       Country Name Country Code     Indicator Name Indicator Code  Year  \
# 10520        Aruba          ABW  Population, total    SP.POP.TOTL  2000
# 10521  Afghanistan          AFG  Population, total    SP.POP.TOTL  2000
# 10522       Angola          AGO  Population, total    SP.POP.TOTL  2000
# 10523      Albania          ALB  Population, total    SP.POP.TOTL  2000
# 10524      Andorra          AND  Population, total    SP.POP.TOTL  2000
#
#        Population
# 10520     90853.0
# 10521  20093756.0
# 10522  16440924.0
# 10523   3089027.0
# 10524     65390.0

# %%
len(pop_data_clean)
# Out:
# 4734

# %%
# Set the index of the gdp DataFrame to the country name
gdp_combined_df = gdp_combined_df.set_index("Country Name")
gdp_combined_df.head()
# Out:
#              Country Code     Indicator Name  Indicator Code  Year  \
# Country Name
# Aruba                 ABW  GDP (current US$)  NY.GDP.MKTP.CD  1960
# Afghanistan           AFG  GDP (current US$)  NY.GDP.MKTP.CD  1960
# Angola                AGO  GDP (current US$)  NY.GDP.MKTP.CD  1960
# Albania               ALB  GDP (current US$)  NY.GDP.MKTP.CD  1960
# Andorra               AND  GDP (current US$)  NY.GDP.MKTP.CD  1960
#
#                       GDP
# Country Name
# Aruba                 NaN
# Afghanistan   537777811.1
# Angola                NaN
# Albania               NaN
# Andorra               NaN

# %%
len(gdp_combined_df.index)
# Out:
# 15312

# %%
# With the index, we can drop the rows for a single country with its name Not clasifed inside gdp dataframe
gdp_combined_df = gdp_combined_df.drop("Not classified")

# %%
len(gdp_combined_df)
# Out:
# 15254

# %%
gdp_combined_df.reset_index()
gdp_combined_df.head()
# Out:
#    index Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 0      0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 1      1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 2      2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 3      3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 4      4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD  1960
#
#            GDP
# 0          NaN
# 1  537777811.1
# 2          NaN
# 3          NaN
# 4          NaN

# %%
gdp_combined_df["Year"] = gdp_combined_df['Year'].astype(str).astype(int)
print(gdp_combined_df.dtypes)
# Out:
# index               int64
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# Year                int32
# GDP               float64
# dtype: object

# %%
# remove rows using the drop() function from gdp_combined_df data frame
gdp_combined_df.drop(gdp_combined_df.loc[gdp_combined_df['Year'] <= 1999].index, inplace=True)
gdp_data_clean = gdp_combined_df
# display the dataframe
gdp_data_clean.head()
# Out:
#        index Country Name Country Code     Indicator Name  Indicator Code  \
# 10520  10520        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 10521  10521  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 10522  10522       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 10523  10523      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 10524  10524      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
#
#        Year           GDP
# 10520  2000  1.873453e+09
# 10521  2000           NaN
# 10522  2000  9.129635e+09
# 10523  2000  3.632044e+09
# 10524  2000  1.434430e+09

# %%
len(gdp_data_clean)
# Out:
# 4734

# %%
pop_data_clean.to_csv(r'C:\Git\WorldBank_ETL\Resources\population_data_clean.csv', encoding='utf-8')

# %%
gdp_data_clean.to_csv(r'C:\Git\WorldBank_ETL\Resources\gdp_data_clean.csv', encoding='utf-8')
