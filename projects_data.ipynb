# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Name of the CSV file
projfile = r"C:\Users\sgodk\Documents\GATECH_Course\python\13-Project-2\2\Resources\projects_data.csv"

# %%
# The correct encoding must be used to read the CSV in pandas
projdf = pd.read_csv(projfile)
# Out:
# C:\Users\sgodk\anaconda4\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
projdf.head()
# Out:
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %%
newprojdf = projdf[['id','regionname','countryname','prodline','lendinginstr','lendinginstrtype','envassesmentcategorycode','supplementprojectflg','productlinetype','projectstatusdisplay','status','project_name','boardapprovaldate','closingdate','lendprojectcost','totalamt','grantamt','goal','url']]

# %%
# list_of_values = ['AD','IN']
filterdf = newprojdf.loc[((newprojdf["lendinginstrtype"] == "AD") | (newprojdf["lendinginstrtype"] == "IN" )) & ((newprojdf["envassesmentcategorycode"] == 'A') | (newprojdf["envassesmentcategorycode"] == 'B')| (newprojdf["envassesmentcategorycode"] == 'C') | (newprojdf["envassesmentcategorycode"] == 'D')) &  newprojdf["projectstatusdisplay"] != '' ] 
filterdf.head()
# Out:
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %%
countrydf  = pd.DataFrame(filterdf['countryname'].str.split(';', expand=True))
bapdtdf = pd.DataFrame(filterdf['boardapprovaldate'].str.split('T', expand=True))
closdtdf = pd.DataFrame(filterdf['closingdate'].str.split('T', expand=True))

# %%
filterdf = filterdf.drop(columns=['countryname','boardapprovaldate','closingdate'])
filterdf["country"] = countrydf[0]
filterdf["boardapprovaldate"] = bapdtdf[0]
filterdf["closingdate"] = closdtdf[0]
filterdf = filterdf[['id','regionname','country','prodline','lendinginstr','lendinginstrtype','envassesmentcategorycode','supplementprojectflg','productlinetype','projectstatusdisplay','status','project_name','boardapprovaldate','closingdate','lendprojectcost','totalamt','grantamt','goal','url']]
filterdf
# Out:
#             id                   regionname                           country  \
# 0      P162228                        Other                             World
# 1      P163962                       Africa  Democratic Republic of the Congo
# 2      P167672                   South Asia   People's Republic of Bangladesh
# 3      P158768                   South Asia  Islamic  Republic of Afghanistan
# 4      P161364                       Africa       Federal Republic of Nigeria
# ...        ...                          ...                               ...
# 18243  P006578  Latin America and Caribbean                 Republic of Chile
# 18244  P037451      Europe and Central Asia         Grand Duchy of Luxembourg
# 18245  P037362      Europe and Central Asia                Kingdom of Denmark
# 18246  P037452      Europe and Central Asia        Kingdom of the Netherlands
# 18247  P037383      Europe and Central Asia                   French Republic
#
# ...
